# %%
import pandas as pd
import pickle as pk
import numpy as np
from numpy import *
import re
from save_ipython_variables import load_all_variables, save_variable
from datetime import timedelta,datetime
import matplotlib as mpl
import matplotlib.pyplot as plt
# -*- coding: utf-8 -*-   
#import mpld3
#mpld3.enable_notebook()
import numpy.linalg as lg

# %%
csv=pd.read_csv("data.csv")
data=pd.DataFrame(csv).T
string=[]
for i in range(10):
    string.append(str(i))
data.index=string
data
# Out:
#               0             1             2             3              4   \
# 0     912.613652    120.439038    230.065918    120.987093     599.476761
# 1       2.880363     36.062195     17.159696     24.310776      11.476382
# 2     180.145935      1.815929     35.290164      9.317461     112.632488
# 3       0.588944     11.120575      5.470542      7.511912       3.288515
# 4     -10.233172      0.556417      3.454839      1.322924       6.743114
# 5    3640.916719    698.684832   1438.004333    963.789746    3580.682477
# 6    -912.910286   -119.897488   -229.355054   -121.372454    -598.449144
# 7       3.991319      5.803348      6.248795      7.971951       5.973925
# 8      -1.720571      2.427723      0.468113      0.774731      -0.346668
# 9  833406.310700  14375.905380  52604.431540  14731.608060  358141.321200
#
#             5            6             7               8              9   \
# 0    59.791690    58.636998    101.586039     1272.150983     991.270634
# ...

# %%
multiply=pd.DataFrame()
for i in range(len(data.ix[:])):
    for j in range(i,len(data.ix[:])):
        multiply=multiply.append(pd.Series(data.ix[i]*data.ix[j],name=(str(i)+str(j))))
multiply
# Out:
#               0             1             2             3             4   \
# 00  8.328637e+05  1.450556e+04  5.293033e+04  1.463788e+04  3.593724e+05
# 01  2.628659e+03  4.343296e+03  3.947861e+03  2.941290e+03  6.879824e+03
# 02  1.644036e+05  2.187088e+02  8.119064e+03  1.127293e+03  6.752056e+04
# 03  5.374782e+02  1.339351e+03  1.258585e+03  9.088444e+02  1.971388e+03
# 04 -9.338932e+03  6.701437e+01  7.948407e+02  1.600568e+02  4.042340e+03
# 05  3.322750e+06  8.414893e+04  3.308358e+05  1.166061e+05  2.146536e+06
# 06 -8.331344e+05 -1.444034e+04 -5.276678e+04 -1.468450e+04 -3.587564e+05
# 07  3.642532e+03  6.989497e+02  1.437635e+03  9.645031e+02  3.581229e+03
# 08 -1.570217e+03  2.923926e+02  1.076968e+02  9.373242e+01 -2.078191e+02
# 09  7.605780e+08  1.731420e+06  1.210249e+07  1.782334e+06  2.146974e+08
# 11  8.296493e+00  1.300482e+03  2.944552e+02  5.910138e+02  1.317073e+02
